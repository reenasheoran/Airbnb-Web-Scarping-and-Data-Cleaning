# %% [markdown]
# <a href="https://colab.research.google.com/github/reenasheoran/Airbnb-Web-Scarping-and-Data-Cleaning/blob/main/Fruit_image_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir image_classifier

# %%
# !mkdir image_classifier/images

# %%
# !mkdir image_classifier/images/apple

# %%
# !mkdir image_classifier/images/mango

# %%
# !mkdir image_classifier/images/Orange

# %%
# !mkdir image_classifier/images/Banana

# %%
# !mkdir image_classifier/images/Grapes

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# ...
# time: 198 µs (started: 2021-05-27 05:09:20 +00:00)

# %%
#### Preprocessing
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize
# Out:
# time: 1.62 ms (started: 2021-05-27 05:45:33 +00:00)

# %%
target_image=[]
input_images=[]
flatted_data=[]
# Out:
# time: 1.42 ms (started: 2021-05-27 05:22:24 +00:00)

# %%
IMAGE_DIR="/content/image_classifier/images"
Categories = ['Apple','Mango','Banana','Grapes','Orange']
# Out:
# time: 1.29 ms (started: 2021-05-27 05:27:57 +00:00)

# %%
for category in Categories:
  Cat_num = Categories.index(category)
  Img_Dir_Path = os.path.join(IMAGE_DIR,category)
  for image in os.listdir(Img_Dir_Path):
    img = imread(os.path.join(Img_Dir_Path,image))
    plt.imshow(img)
    break
# Out:
# time: 330 ms (started: 2021-05-27 05:50:25 +00:00)
